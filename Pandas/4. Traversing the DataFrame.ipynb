# %%
import numpy as np
import pandas as pd

# %%
datasetExample = pd.read_csv('FinalOutput.csv')

# %%
datasetExample
# Out:
#    eid     ename  esal  yearlySalary department  UpdatedSalary  \
# 0    1  Prashant  1000         12000         HR        1100.00
# 1    2      Amar  2000         24000        Ops        2100.00
# 2    3    Chitra  2000         24000      Admin        2100.00
# 3    3    Chitra  2000         24000      Admin        2100.00
# 4    4  Utkarsha  9878        118536        Ops       10371.90
# 5    5      Ajit  9999        119988         HR       10498.95
#
#    UpdatedYearlySalary
# 0              13200.0
# 1              25200.0
# 2              25200.0
# 3              25200.0
# 4             124462.8
# 5             125987.4

# %%
# first 3 records 
# ename,dept,UpdatedSalary
datasetExample.iloc[ 0:3 , [1,4,5]]
# Out:
#       ename department  UpdatedSalary
# 0  Prashant         HR         1100.0
# 1      Amar        Ops         2100.0
# 2    Chitra      Admin         2100.0

# %%
# first 3 records 
# UpdatedSalary,ename,dept
datasetExample.iloc[ 0:3 , [5,1,4]]
# Out:
#    UpdatedSalary     ename department
# 0         1100.0  Prashant         HR
# 1         2100.0      Amar        Ops
# 2         2100.0    Chitra      Admin

# %%
# Data Traversal
# Type1 -- Traversing the data using Index
#
# iloc --> indexLocation
# iloc[rowIndex/rowRange/rowList , columnIndex/columnRange/columnList]


datasetExample.iloc[ 0:3 , :]
# Out:
#    eid     ename  esal  yearlySalary department  UpdatedSalary  \
# 0    1  Prashant  1000         12000         HR         1100.0
# 1    2      Amar  2000         24000        Ops         2100.0
# 2    3    Chitra  2000         24000      Admin         2100.0
#
#    UpdatedYearlySalary
# 0              13200.0
# 1              25200.0
# 2              25200.0

# %%
datasetExample.iloc[ 0:3 , 0:4]
# Out:
#    eid     ename  esal  yearlySalary
# 0    1  Prashant  1000         12000
# 1    2      Amar  2000         24000
# 2    3    Chitra  2000         24000

# %%
datasetExample.iloc[ 0:3 , [0,4] ]
# Out:
#    eid department
# 0    1         HR
# 1    2        Ops
# 2    3      Admin
